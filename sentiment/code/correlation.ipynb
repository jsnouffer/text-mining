# %%
import pandas as pd
import ast
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

FILE = '/home/jason/notebooks/sentiment/grid.out'

with open(FILE) as f:
   df = pd.DataFrame([ast.literal_eval(row.value) for row in ast.parse(f.read()).body])
df.shape
# Out:
# (6272, 8)

# %%
df.head()
# Out:
#       C  dual  fit_intercept  intercept_scaling multi_class     solver  \
# 0  0.01  True           True               0.01         ovr  liblinear
# 1  0.01  True           True               0.01         ovr  liblinear
# 2  0.01  True           True               0.01         ovr  liblinear
# 3  0.01  True           True               0.01         ovr  liblinear
# 4  0.01  True           True               0.01         ovr  liblinear
#
#       tol   score
# 0  0.0010  0.6935
# 1  0.0012  0.6935
# 2  0.0014  0.6935
# 3  0.0016  0.6935
# 4  0.0018  0.6935

# %%
[ df['score'].max(), df['score'].min() ]
# Out:
# ['0.732', '0.4985']

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['intercept_scaling'], label="intercept_scaling")
#plt.legend(loc='upper left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['solver'], label="solver")
#plt.legend(loc='upper left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['dual'], label="dual")
plt.legend(loc='center left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['C'], label="C")
plt.legend(loc='center left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['fit_intercept'], label="fit_intercept")
plt.legend(loc='center left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['multi_class'], label="multi_class")
#plt.legend(loc='center left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['tol'], label="tol")
plt.legend(loc='upper left')
plt.show()
