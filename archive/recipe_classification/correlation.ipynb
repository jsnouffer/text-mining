# %%
import pandas as pd
import ast
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

FILE = '/home/jason/grid_search.out'

with open(FILE) as f:
   df = pd.DataFrame([ast.literal_eval(row.value) for row in ast.parse(f.read()).body])
df
# Out:
#      C class_weight decision_function_shape  gamma kernel  max_df  min_df  \
# 0   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 1   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 2   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 3   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 4   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 5   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 6   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 7   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 8   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 9   47     balanced                     ovo   1.68    rbf    0.65     0.0
# 10  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 11  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 12  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 13  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 14  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 15  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 16  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 17  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 18  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 19  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 20  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 21  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 22  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 23  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 24  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 25  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 26  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 27  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 28  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 29  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 30  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 31  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 32  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 33  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 34  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 35  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 36  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 37  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 38  47     balanced                     ovo   1.68    rbf    0.65     0.0
# 39  47     balanced                     ovo   1.68    rbf    0.65     0.0
#
#     polynomial_coef0  polynomial_degree  remove_singleton_recipes  seed  \
# 0                  2                  1                     False    42
# 1                  2                  1                     False    42
# 2                  2                  1                     False    42
# 3                  2                  1                     False    42
# 4                  2                  1                     False    42
# 5                  2                  1                     False    42
# 6                  2                  1                     False    42
# 7                  2                  1                     False    42
# 8                  2                  1                     False    42
# 9                  2                  1                     False    42
# 10                 2                  1                     False    42
# 11                 2                  1                     False    42
# 12                 2                  1                     False    42
# 13                 2                  1                     False    42
# 14                 2                  1                     False    42
# 15                 2                  1                     False    42
# 16                 2                  1                     False    42
# 17                 2                  1                     False    42
# 18                 2                  1                     False    42
# 19                 2                  1                     False    42
# 20                 2                  1                     False    42
# 21                 2                  1                     False    42
# 22                 2                  1                     False    42
# 23                 2                  1                     False    42
# 24                 2                  1                     False    42
# 25                 2                  1                     False    42
# 26                 2                  1                     False    42
# 27                 2                  1                     False    42
# 28                 2                  1                     False    42
# 29                 2                  1                     False    42
# 30                 2                  1                     False    42
# 31                 2                  1                     False    42
# 32                 2                  1                     False    42
# 33                 2                  1                     False    42
# 34                 2                  1                     False    42
# 35                 2                  1                     False    42
# 36                 2                  1                     False    42
# 37                 2                  1                     False    42
# 38                 2                  1                     False    42
# 39                 2                  1                     False    42
#
#     shrinking  smooth_idf strip_accents  sublinear_tf tfidf_norm     tol  \
# 0        True       False          None          True         l1  0.0010
# 1        True       False          None          True         l1  0.0012
# 2        True       False          None          True         l1  0.0014
# 3        True       False          None          True         l1  0.0016
# 4        True       False          None          True         l1  0.0018
# 5        True       False          None          True         l1  0.0020
# 6        True       False          None          True         l1  0.0022
# 7        True       False          None          True         l1  0.0024
# 8        True       False          None          True         l1  0.0026
# 9        True       False          None          True         l1  0.0028
# 10       True       False          None          True         l1  0.0030
# 11       True       False          None          True         l1  0.0032
# 12       True       False          None          True         l1  0.0034
# 13       True       False          None          True         l1  0.0036
# 14       True       False          None          True         l1  0.0038
# 15       True       False          None          True         l1  0.0040
# 16       True       False          None          True         l1  0.0042
# 17       True       False          None          True         l1  0.0044
# 18       True       False          None          True         l1  0.0046
# 19       True       False          None          True         l1  0.0048
# 20       True       False          None          True         l1  0.0050
# 21       True       False          None          True         l1  0.0052
# 22       True       False          None          True         l1  0.0054
# 23       True       False          None          True         l1  0.0056
# 24       True       False          None          True         l1  0.0058
# 25       True       False          None          True         l1  0.0060
# 26       True       False          None          True         l1  0.0062
# 27       True       False          None          True         l1  0.0064
# 28       True       False          None          True         l1  0.0066
# 29       True       False          None          True         l1  0.0068
# 30       True       False          None          True         l1  0.0070
# 31       True       False          None          True         l1  0.0072
# 32       True       False          None          True         l1  0.0074
# 33       True       False          None          True         l1  0.0076
# 34       True       False          None          True         l1  0.0078
# 35       True       False          None          True         l1  0.0080
# 36       True       False          None          True         l1  0.0082
# 37       True       False          None          True         l1  0.0084
# 38       True       False          None          True         l1  0.0086
# 39       True       False          None          True         l1  0.0088
#
#     use_idf  count     score
# 0      True      1  0.794238
# 1      True      2  0.794238
# 2      True      3  0.794213
# 3      True      4  0.794238
# 4      True      5  0.794238
# 5      True      6  0.794238
# 6      True      7  0.794238
# 7      True      8  0.794187
# 8      True      9  0.794213
# 9      True     10  0.794238
# 10     True     11  0.794238
# 11     True     12  0.794238
# 12     True     13  0.794137
# 13     True     14  0.794238
# 14     True     15  0.794213
# 15     True     16  0.794263
# 16     True     17  0.794238
# 17     True     18  0.794313
# 18     True     19  0.794238
# 19     True     20  0.794338
# 20     True     21  0.794238
# 21     True     22  0.794238
# 22     True     23  0.794288
# 23     True     24  0.794238
# 24     True     25  0.794238
# 25     True     26  0.794313
# 26     True     27  0.794238
# 27     True     28  0.794288
# 28     True     29  0.794288
# 29     True     30  0.794288
# 30     True     31  0.794238
# 31     True     32  0.794313
# 32     True     33  0.794213
# 33     True     34  0.794238
# 34     True     35  0.794288
# 35     True     36  0.794288
# 36     True     37  0.794238
# 37     True     38  0.794263
# 38     True     39  0.794338
# 39     True     40  0.794288

# %%
np.max(df['score'])
# Out:
# 0.7943382492203033

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['gamma'], label="Gamma")
plt.legend(loc='upper left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['polynomial_degree'], label="polynomial_degree")
#plt.legend(loc='upper left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['C'], label="C")
plt.legend(loc='upper left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['decision_function_shape'], label="decision_function_shape")
plt.legend(loc='center left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['polynomial_coef0'], label="polynomial_coef0")
plt.legend(loc='center left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['tol'], label="tol")
plt.legend(loc='upper left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(df['score'], df['class_weight'].replace(to_replace=[None], value='none'), label="class_weight")
plt.legend(loc='center left')
plt.show()

# %%
# %matplotlib inline
matplotlib.style.use('ggplot')

q = df['score'] > 0.63
q1 = df['C'] <= 10
s = df['score'][q]
c = df['C'][q]
tol = df['tol'][q]

plt.scatter(s, c, label="C")
plt.legend(loc='upper left')
plt.show()
plt.scatter(s, tol, label="tol")
plt.legend(loc='upper left')
plt.show()

# %%
df.plot(x='score', y='C', kind='hexbin')
